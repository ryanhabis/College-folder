# %%
# Import needed libraries
import numpy as np
import pandas as pd
import os

# %%
# Read the CSV file directly using pandas
df = pd.read_csv("/home/ryanhabis/Documents/College folder/semester-1/Programming for Data Analytics/dataset/Dataset- Superstore (2015-2018).csv")

# %%
# open the csv file using read_csv, no need to use delimitator (parameter 'sep'in read_csv)
# pl = pd.read_csv("pl_2seasons.csv")
# display(pl.iloc[:10]) # show the first ten rows, also you can use pl.head(10)

# %%
df.head()  # Display the first few rows of the dataframe
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016/06/12  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# City -> category -> sales.mean()
city_category_sales = df.groupby(['City', 'Category'])['Sales'].mean()

# %%
city_category_sales.head()  # Display the first few results
# Out:
# City      Category
# Aberdeen  Office Supplies     25.500000
# Abilene   Office Supplies      1.392000
# Akron     Furniture          216.798000
#           Office Supplies     79.527714
#           Technology         236.600400
# Name: Sales, dtype: float64

# %%
# group data by year in each city and tell which city has maximum sales by year (added sum mean to the question)

group_Data_By_Year = df.groupby(['Ship Date', 'City'])['Sales'].agg(['sum', 'mean', 'max'])
group_Data_By_Year.head()
# Out:
#                              sum        mean       max
# Ship Date  City
# 2014/01/07 Athens         12.780   12.780000    12.780
#            Houston        16.448   16.448000    16.448
# 2014/01/08 Los Angeles    19.440   19.440000    19.440
#            Naperville    288.060   96.020000   272.736
# 2014/01/10 Henderson    4374.880  624.982857  2573.820

# %%
# display(df.groupby(['Season','HomeTeam'])[['FTHG','FTAG']].agg(['sum','max','count','mean']))

#I want to make this code work for this dataset

display(df.groupby(['Order ID','Customer Name'])[['Sales']].agg(['sum','max','count','mean']))
# Out:
#                                      Sales
#                                        sum      max count        mean
# Order ID       Customer Name
# CA-2014-100006 Dennis Kane         377.970  377.970     1  377.970000
# CA-2014-100090 Ed Braxton          699.192  502.488     2  349.596000
# CA-2014-100293 Neil Französisch     91.056   91.056     1   91.056000
# CA-2014-100328 Jasper Cacioppo       3.928    3.928     1    3.928000
# CA-2014-100363 Jim Mitchum          21.376   19.008     2   10.688000
# ...                                    ...      ...   ...         ...
# US-2017-168802 Jack O'Briant        18.368   18.368     1   18.368000
# US-2017-169320 Lena Hernandez      171.430  159.750     2   85.715000
# US-2017-169488 Allen Armold         56.860   39.960     2   28.430000
# US-2017-169502 Matthew Grinstein   113.410   91.600     2   56.705000
# US-2017-169551 Rob Lucas          1344.838  683.988     6  224.139667
#
# [5009 rows x 4 columns]

# %%
#df = pd.DataFrame({"data1": [12, 34, 23, 45],
#                  "data2": [23, 43, 56, 23]},

#                  index=["a", "b", "c", "d"])

#df

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
#df.set_index(['State','City'], inplace = True)

group_by_State_City = df.set_index(['State','City'])

# %%
display(group_by_State_City)
# Out:
#                             Row ID        Order ID  Order Date   Ship Date  \
# State      City
# Kentucky   Henderson             1  CA-2016-152156  2016/11/08  2016/11/11
#            Henderson             2  CA-2016-152156  2016/11/08  2016/11/11
# California Los Angeles           3  CA-2016-138688  2016/06/12  2016/06/16
# Florida    Fort Lauderdale       4  US-2015-108966  2015/10/11  2015/10/18
#            Fort Lauderdale       5  US-2015-108966  2015/10/11  2015/10/18
# ...                            ...             ...         ...         ...
#            Miami              9990  CA-2014-110422  2014/01/21  2014/01/23
# California Costa Mesa         9991  CA-2017-121258  2017/02/26  2017/03/03
#            Costa Mesa         9992  CA-2017-121258  2017/02/26  2017/03/03
#            Costa Mesa         9993  CA-2017-121258  2017/02/26  2017/03/03
#            Westminster        9994  CA-2017-119914  2017/05/04  2017/05/09
#
# ...

# %%
data['Ship Date'] = pd.to_datetime(date['Ship Date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[325], line 1
# ----> 1 df['Ship Date'] = pd.to_datetime(date['Ship Date'])
#
# NameError: name 'date' is not defined

# %%
data['Year'] = pd.to_datetime(date['Ship Date'])
