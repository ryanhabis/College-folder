# %%
import pandas as pd

# %%
file_path = '/home/ryanhabis/Documents/College folder/semester-1/Programming for Data Analytics/dataset/Dataset- Superstore (2015-2018).csv'
sales_data = pd.read_csv(file_path)

# %%
sales_data.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016/06/12  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
sales_data.shape
# Out:
# (9994, 21)

# %%
sales_data.Country
# Out:
# 0       United States
# 1       United States
# 2       United States
# 3       United States
# 4       United States
#             ...
# 9989    United States
# 9990    United States
# 9991    United States
# 9992    United States
# 9993    United States
# Name: Country, Length: 9994, dtype: object

# %%
subset = sales_data[['Country', 'City', 'State', 'Sales', 'Profit']]

# %% [markdown]
# Two ways to display.

# %%
display(subset)
# Out:
#             Country             City       State     Sales    Profit
# 0     United States        Henderson    Kentucky  261.9600   41.9136
# 1     United States        Henderson    Kentucky  731.9400  219.5820
# 2     United States      Los Angeles  California   14.6200    6.8714
# 3     United States  Fort Lauderdale     Florida  957.5775 -383.0310
# 4     United States  Fort Lauderdale     Florida   22.3680    2.5164
# ...             ...              ...         ...       ...       ...
# 9989  United States            Miami     Florida   25.2480    4.1028
# 9990  United States       Costa Mesa  California   91.9600   15.6332
# 9991  United States       Costa Mesa  California  258.5760   19.3932
# 9992  United States       Costa Mesa  California   29.6000   13.3200
# 9993  United States      Westminster  California  243.1600   72.9480
#
# [9994 rows x 5 columns]

# %%
print(subset)
# Out:
#             Country             City       State     Sales    Profit
# 0     United States        Henderson    Kentucky  261.9600   41.9136
# 1     United States        Henderson    Kentucky  731.9400  219.5820
# 2     United States      Los Angeles  California   14.6200    6.8714
# 3     United States  Fort Lauderdale     Florida  957.5775 -383.0310
# 4     United States  Fort Lauderdale     Florida   22.3680    2.5164
# ...             ...              ...         ...       ...       ...
# 9989  United States            Miami     Florida   25.2480    4.1028
# 9990  United States       Costa Mesa  California   91.9600   15.6332
# 9991  United States       Costa Mesa  California  258.5760   19.3932
# 9992  United States       Costa Mesa  California   29.6000   13.3200
# 9993  United States      Westminster  California  243.1600   72.9480
#
# [9994 rows x 5 columns]

# %%
sales_data.iloc[0:5, :]  # first 5 rows and first 5 columns
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016/11/08  2016/11/11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016/06/12  2016/06/16    Second Class    DV-13045
# 3       4  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015/10/11  2015/10/18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
specific_data = sales_data.iloc[[0,50,100],[0,5]]  # specific rows and columns
display(specific_data)
# Out:
#      Row ID Customer ID
# 0         1    CG-12520
# 50       51    DP-13000
# 100     101    RB-19465

# %%
last_five = sales_data.iloc[-5:, :]  # last 5 rows
display(last_five)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9989    9990  CA-2014-110422  2014/01/21  2014/01/23    Second Class
# 9990    9991  CA-2017-121258  2017/02/26  2017/03/03  Standard Class
# 9991    9992  CA-2017-121258  2017/02/26  2017/03/03  Standard Class
# 9992    9993  CA-2017-121258  2017/02/26  2017/03/03  Standard Class
# 9993    9994  CA-2017-119914  2017/05/04  2017/05/09    Second Class
#
#      Customer ID     Customer Name   Segment        Country         City  ...  \
# 9989    TB-21400  Tom Boeckenhauer  Consumer  United States        Miami  ...
# 9990    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9991    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9992    DB-13060       Dave Brooks  Consumer  United States   Costa Mesa  ...
# 9993    CC-12220      Chris Cortes  Consumer  United States  Westminster  ...
#
#      Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data = sales_data.iloc[1:8:,2:5] 
display(data)
# Out:
#    Order Date   Ship Date       Ship Mode
# 1  2016/11/08  2016/11/11    Second Class
# 2  2016/06/12  2016/06/16    Second Class
# 3  2015/10/11  2015/10/18  Standard Class
# 4  2015/10/11  2015/10/18  Standard Class
# 5  2014/06/09  2014/06/14  Standard Class
# 6  2014/06/09  2014/06/14  Standard Class
# 7  2014/06/09  2014/06/14  Standard Class

# %%
sales_data.iloc[-10:,:]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251  2015/05/17  2015/05/23  Standard Class
# 9985    9986  CA-2015-100251  2015/05/17  2015/05/23  Standard Class
# 9986    9987  CA-2016-125794  2016/09/29  2016/10/03  Standard Class
# 9987    9988  CA-2017-163629  2017/11/17  2017/11/21  Standard Class
# 9988    9989  CA-2017-163629  2017/11/17  2017/11/21  Standard Class
# 9989    9990  CA-2014-110422  2014/01/21  2014/01/23    Second Class
# 9990    9991  CA-2017-121258  2017/02/26  2017/03/03  Standard Class
# 9991    9992  CA-2017-121258  2017/02/26  2017/03/03  Standard Class
# 9992    9993  CA-2017-121258  2017/02/26  2017/03/03  Standard Class
# 9993    9994  CA-2017-119914  2017/05/04  2017/05/09    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %%
sales_data.iloc[[100],[10]]
# Out:
#         State
# 100  Illinois

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
subset = sales_data.loc[:,["Sales","Profit"]]

print(subset)
# Out:
#          Sales    Profit
# 0     261.9600   41.9136
# 1     731.9400  219.5820
# 2      14.6200    6.8714
# 3     957.5775 -383.0310
# 4      22.3680    2.5164
# ...        ...       ...
# 9989   25.2480    4.1028
# 9990   91.9600   15.6332
# 9991  258.5760   19.3932
# 9992   29.6000   13.3200
# 9993  243.1600   72.9480
#
# [9994 rows x 2 columns]

# %%
sales_data["Order Date"] = pd.to_datetime(sales_data["Order Date"])
print(sales_data["Order Date"])
# Out:
# 0      2016-11-08
# 1      2016-11-08
# 2      2016-06-12
# 3      2015-10-11
# 4      2015-10-11
#           ...
# 9989   2014-01-21
# 9990   2017-02-26
# 9991   2017-02-26
# 9992   2017-02-26
# 9993   2017-05-04
# Name: Order Date, Length: 9994, dtype: datetime64[ns]

# %%
sales_data = sales_data.set_index("Order Date")
print(sales_data)
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156  2016/11/11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156  2016/11/11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688  2016/06/16    Second Class    DV-13045
# 2015-10-11       4  US-2015-108966  2015/10/18  Standard Class    SO-20335
# 2015-10-11       5  US-2015-108966  2015/10/18  Standard Class    SO-20335
# ...            ...             ...         ...             ...         ...
# 2014-01-21    9990  CA-2014-110422  2014/01/23    Second Class    TB-21400
# 2017-02-26    9991  CA-2017-121258  2017/03/03  Standard Class    DB-13060
# 2017-02-26    9992  CA-2017-121258  2017/03/03  Standard Class    DB-13060
# 2017-02-26    9993  CA-2017-121258  2017/03/03  Standard Class    DB-13060
# 2017-05-04    9994  CA-2017-119914  2017/05/09    Second Class    CC-12220
#
# ...

# %%
sales_data = sales_data.sort_values(by="Order Date")
print(sales_data)
# Out:
#             Row ID        Order ID   Ship Date       Ship Mode Customer ID  \
# Order Date
# 2014-01-03    7981  CA-2014-103800  2014/01/07  Standard Class    DP-13000
# 2014-01-04     740  CA-2014-112326  2014/01/08  Standard Class    PO-19195
# 2014-01-04     741  CA-2014-112326  2014/01/08  Standard Class    PO-19195
# 2014-01-04     742  CA-2014-112326  2014/01/08  Standard Class    PO-19195
# 2014-01-05    1760  CA-2014-141817  2014/01/12  Standard Class    MB-18085
# ...            ...             ...         ...             ...         ...
# 2017-12-30    5092  CA-2017-156720  2018/01/03  Standard Class    JM-15580
# 2017-12-30     909  CA-2017-143259  2018/01/03  Standard Class    PO-18865
# 2017-12-30     908  CA-2017-143259  2018/01/03  Standard Class    PO-18865
# 2017-12-30    1297  CA-2017-115427  2018/01/03  Standard Class    EB-13975
# 2017-12-30     907  CA-2017-143259  2018/01/03  Standard Class    PO-18865
#
# ...

# %%
# ensure the DatetimeIndex is monotonic before label-based slicing
sales_2017 = sales_data.sort_index().loc['2017-01-01':'2017-12-31', ["Sales","Profit"]]

# %%
sales_data["Ship Date"] = pd.to_datetime(sales_data["Ship Date"])
sales_data = sales_data.sort_values(by="Ship Date")
print(sales_data)
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2014-01-03    7981  CA-2014-103800 2014-01-07  Standard Class    DP-13000
# 2014-01-06    7181  CA-2014-106054 2014-01-07     First Class    JO-15145
# 2014-01-04     740  CA-2014-112326 2014-01-08  Standard Class    PO-19195
# 2014-01-04     741  CA-2014-112326 2014-01-08  Standard Class    PO-19195
# 2014-01-04     742  CA-2014-112326 2014-01-08  Standard Class    PO-19195
# ...            ...             ...        ...             ...         ...
# 2017-12-29    4240  CA-2017-158673 2018-01-04  Standard Class    KB-16600
# 2017-12-28     574  CA-2017-164826 2018-01-04  Standard Class    JF-15415
# 2017-12-28     571  CA-2017-164826 2018-01-04  Standard Class    JF-15415
# 2017-12-30     646  CA-2017-126221 2018-01-05  Standard Class    CC-12430
# 2017-12-29    5132  CA-2017-146626 2018-01-05  Standard Class    BP-11185
#
# ...

# %%
high_profit = sales_data[(sales_data["Profit"] > 100) & (sales_data["Sales"] < 500)]
print(high_profit)
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2014-01-06    7478  CA-2014-167199 2014-01-10  Standard Class    ME-17320
# 2014-02-01     541  CA-2014-140795 2014-02-03     First Class    BD-11500
# 2014-02-11    5631  CA-2014-127614 2014-02-15  Standard Class    NF-18385
# 2014-03-05    8498  CA-2014-169061 2014-03-08    Second Class    AB-10150
# 2014-03-30    7630  CA-2014-162089 2014-04-01     First Class    MP-17470
# ...            ...             ...        ...             ...         ...
# 2017-12-22    8178  CA-2017-149699 2017-12-24     First Class    CM-12115
# 2017-12-20    6509  CA-2017-102197 2017-12-26  Standard Class    DK-13150
# 2017-12-24    4030  CA-2017-124296 2017-12-28  Standard Class    CS-12355
# 2017-12-23    6854  US-2017-162670 2017-12-28    Second Class    MF-18250
# 2017-12-29    4240  CA-2017-158673 2018-01-04  Standard Class    KB-16600
#
# ...

# %%
high_profit = sales_data.loc[(sales_data["Category"] == "Technology") & (sales_data["Sales"] < 500), ["Category","Sales","Profit"]]
print(high_profit)
# Out:
#               Category    Sales    Profit
# Order Date
# 2014-01-06  Technology  391.980  113.6742
# 2014-01-09  Technology   31.200    9.7500
# 2014-01-15  Technology  149.950   65.9780
# 2014-01-16  Technology  124.200  -31.0500
# 2014-01-26  Technology  187.980   52.6344
# ...                ...      ...       ...
# 2017-12-25  Technology   31.800   13.6740
# 2017-12-25  Technology  158.928   41.7186
# 2017-12-29  Technology  302.376   22.6782
# 2017-12-30  Technology   90.930    2.7279
# 2017-12-28  Technology   14.850    4.0095
#
# [1451 rows x 3 columns]

# %% [markdown]
# select all the rows with "Technology" and sales > 100, and return a datafram with colums category, sales and profit.

# %%
tech_profit = sales_data.loc[(sales_data["Category"] == "Technology") & (sales_data["Sales"] > 100), ["Category","Sales","Profit"]]
print(tech_profit)
# Out:
#               Category    Sales    Profit
# Order Date
# 2014-01-06  Technology  391.980  113.6742
# 2014-01-06  Technology  755.960  204.1092
# 2014-01-13  Technology  646.740  258.6960
# 2014-01-15  Technology  149.950   65.9780
# 2014-01-16  Technology  124.200  -31.0500
# ...                ...      ...       ...
# 2017-12-25  Technology  120.000   -7.2000
# 2017-12-23  Technology  494.970  148.4910
# 2017-12-21  Technology  281.970   78.9516
# 2017-12-25  Technology  158.928   41.7186
# 2017-12-29  Technology  302.376   22.6782
#
# [1187 rows x 3 columns]

# %%
sales_data.isna().sum() # check for missing values
# Out:
# Row ID           0
# Order ID         0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# ensure the DatetimeIndex is monotonic before label-based slicing
sales_2017 = sales_data.sort_index().loc['2017-01-01':'2017-12-31', ["Sales","Profit"]]
print(sales_2017)
# Out:
#               Sales    Profit
# Order Date
# 2017-01-01   15.224  -38.8212
# 2017-01-01   13.748  -22.6842
# 2017-01-01   48.896    8.5568
# 2017-01-01  141.420 -187.3815
# 2017-01-01  454.560 -107.9580
# ...             ...       ...
# 2017-12-30   52.776   19.7910
# 2017-12-30   90.930    2.7279
# 2017-12-30   13.904    4.5188
# 2017-12-30  209.300   56.5110
# 2017-12-30  323.136   12.1176
#
# [3312 rows x 2 columns]

# %%
high_profit = sales_data.loc[(sales_data["Profit"] > 100) & (sales_data["Sales"] < 500), ["Category","Sales","Profit"]]
print(high_profit)
# Out:
#                    Category   Sales    Profit
# Order Date
# 2014-01-06       Technology  391.98  113.6742
# 2014-02-01       Technology  468.90  206.3160
# 2014-02-11       Technology  234.45  103.1580
# 2014-03-05       Technology  479.97  177.5889
# 2014-03-30  Office Supplies  335.72  113.3055
# ...                     ...     ...       ...
# 2017-12-22       Technology  474.95  142.4850
# 2017-12-20  Office Supplies  279.90  137.1510
# 2017-12-23       Technology  494.97  148.4910
# 2017-12-24       Technology  479.97  239.9850
# 2017-12-29  Office Supplies  209.70  100.6560
#
# [260 rows x 3 columns]

# %%
filtered_sales = sales_2017["Sales"].where(sales_2017["Sales"] > 300)
